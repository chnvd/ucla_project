# %% [markdown]
# # Exploration of transit cost data
#
# Through this notebook I hope to
# 1. Clean the excel file into a usable data set.
# 2. Run some descriptive statistics to understand the data set.
#
# ## 1. Data wrangling

# %% [markdown]
# LINE	Name		Country	City	Regional Rail
# Phase 1	IN	Ahmadabad	No
# CONSTRUCTION DETAILS	Start year	End year	Length (in km)	Tunnel (in km)	Tunnel	Stations	Source
# 2015	2023	40.0	6.4	16%	33	Wiki
# COST INFORMATION	Cost (in M)	Currency	PPP rate	Year PPP	Real cost (in M$)	Cost/km (in M$)	Source
# 127000.0	INR	0.05	2019	5969.0	149.2	Media
# REFERENCE	https://indianexpress.com/article/cities/ahmedabad/ahmedabad-metro-phase-1-delay-makes-cost-jump-by-rs-2000-cr-6486037/

# %%
# importing the data and checking the data
import pandas as pd
transitcost = pd.read_excel("transitcost.xlsx")
transitcost.head()
# Out:
#        ID Country       City        Line        Phase Start year End year  \
# 0  9501.0      TR   Istanbul          M4   M4 Phase 3       2015     2022
# 1  7136.0      CA  Vancouver  Millennium     Broadway       2020     2025
# 2  7137.0      CA    Toronto         YUS      Vaughan       2009     2017
# 3  7138.0      CA    Toronto         NaN  Scarborough       2020     2030
# 4  7139.0      CA    Toronto         NaN      Ontario       2020     2030
#
#    RR? Length TunnelPer  ... Clength Ctunnel Anglo? Inflation Index  \
# 0  0.0    7.5         1  ...     7.5     7.5    0.0        1.079102
# 1  0.0    5.7  0.877193  ...     0.0     0.0    1.0        1.079102
# 2  0.0    8.6         1  ...     0.0     0.0    1.0        1.163176
# 3  0.0    7.8         1  ...     0.0     0.0    1.0        1.079102
# 4  0.0   15.5      0.57  ...     0.0     0.0    1.0        1.059897
#
#   Real cost (2021 dollars) Cost/km (2021 dollars) Source2  \
# ...

# %%
transitcost.sample(5)
# Out:
#          ID Country          City    Line                     Phase  \
# 238  7609.0      MY  Kuala Lumpur     NaN    Putrajaya Line (MRT 2)
# 452  8040.0      CN     Guangzhou  Line 3  Line 3 Eastern Extension
# 496  8128.0      CN       Kunming     NaN                    Line 6
# 286  7705.0      CN        Xuzhou     NaN            Line 6 Phase 1
# 951     NaN     NaN           MIN     NaN                  7.793145
#
#     Start year End year  RR?  Length TunnelPer  ... Clength Ctunnel Anglo?  \
# 238       2016     2023  0.0    52.2      0.26  ...     0.0     0.0    0.0
# 452       2019     2022  0.0     9.6         1  ...     0.0     0.0    0.0
# 496       2020      NaN  0.0   25.61      0.59  ...     0.0     0.0    0.0
# 286       2021      NaN  0.0  22.912         1  ...     0.0     0.0    0.0
# 951        NaN      NaN  NaN     NaN       NaN  ...     NaN     NaN    NaN
#
#     Inflation Index Real cost (2021 dollars) Cost/km (2021 dollars) Source2  \
# ...

# %%
transitcost.tail(5)
# Out:
#      ID Country                 City Line           Phase Start year End year  \
# 960 NaN     NaN   T.COST OF PROJECTS  NaN  4166796.382872        NaN      600
# 961 NaN     NaN  AVG COST/KM (W.AVG)  NaN      211.448186        NaN      NaN
# 962 NaN     NaN                  NaN  NaN             NaN        NaN      NaN
# 963 NaN     NaN         59 Countries  NaN             NaN        NaN      NaN
# 964 NaN     NaN           184 Cities  NaN             NaN        NaN      NaN
#
#      RR?     Length TunnelPer  ... Clength Ctunnel Anglo? Inflation Index  \
# 960  NaN  12621.074       NaN  ...     NaN     NaN    NaN             NaN
# 961  NaN        NaN       NaN  ...     NaN     NaN    NaN             NaN
# 962  NaN        NaN       NaN  ...     NaN     NaN    NaN             NaN
# 963  NaN        NaN       NaN  ...     NaN     NaN    NaN             NaN
# 964  NaN        NaN       NaN  ...     NaN     NaN    NaN             NaN
#
# ...

# %% [markdown]
# Rows 0 to 943 contain the data. Rest of the rows seem to have been made by the data collectors for analysis. Lets remove these rows.

# %%
transit = transitcost[:944]
transit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        637 non-null    float64
#  1   Country                   944 non-null    object
#  2   City                      944 non-null    object
#  3   Line                      407 non-null    object
#  4   Phase                     943 non-null    object
#  5   Start year                854 non-null    object
#  6   End year                  726 non-null    object
#  7   RR?                       942 non-null    float64
#  8   Length                    942 non-null    object
#  9   TunnelPer                 879 non-null    object
#  10  Tunnel                    878 non-null    object
#  11  Elevated                  576 non-null    object
#  12  Atgrade                   570 non-null    object
# ...

# %% [markdown]
# Data type erros - many data type that seem to be contiuous variables seem to be identified as objects.

# %%
# converting column names into lower case
transit.columns = [x.lower() for x in transit.columns.tolist()]
transit.info()

import re
transit.columns = [re.sub(r"\s+", "_", x) for x in transit.columns]
transit.columns = [re.sub(r"/", "_p_", x) for x in transit.columns]
transit.columns = [re.sub(r"[^A-z\s0-9]", "", x) for x in transit.columns]
transit.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      637 non-null    float64
#  1   country                 944 non-null    object
#  2   city                    944 non-null    object
#  3   line                    407 non-null    object
#  4   phase                   943 non-null    object
#  5   start_year              854 non-null    object
#  6   end_year                726 non-null    object
#  7   rr                      942 non-null    float64
#  8   length                  942 non-null    object
#  9   tunnelper               879 non-null    object
#  10  tunnel                  878 non-null    object
#  11  elevated                576 non-null    object
#  12  atgrade                 570 non-null    object
#  13  stations                916 non-null    object
# ...

# %%
transit.drop(['id','unnamed_31', 'unnamed_32', 'source1', 'cheap','clength', 'ctunnel', 'anglo', 'source2', 'reference'], 
             axis=1, inplace=True)
transit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 944 non-null    object
#  1   city                    944 non-null    object
#  2   line                    407 non-null    object
#  3   phase                   943 non-null    object
#  4   start_year              854 non-null    object
#  5   end_year                726 non-null    object
#  6   rr                      942 non-null    float64
#  7   length                  942 non-null    object
#  8   tunnelper               879 non-null    object
#  9   tunnel                  878 non-null    object
#  10  elevated                576 non-null    object
#  11  atgrade                 570 non-null    object
#  12  stations                916 non-null    object
#  13  platform_length_meters  411 non-null    object
# ...

# %%
transit.country.unique()
# Out:
# array(['TR', 'CA', 'NL', 'US', 'BG', 'PL', 'RO', 'RU', 'CZ', 'HU', 'FR',
#        'IT', 'FI', 'SE', 'UK', 'MX', 'TW', 'VN', 'KR', 'DE', 'BE', 'DK',
#        'NO', 'AU', 'SG', 'IN', 'GR', 'CL', 'BR', 'PA', 'PH', 'AT', 'IR',
#        'ES', 'PT', 'EC', 'IL', 'NZ', 'BD', 'ID', 'PK', 'TH', 'JP', 'CH',
#        'UA', 'AR', 'PE', 'MY', 'CN', 'SA', 'QA', 'BH', 'AE', 'EG', 'KW',
#        'UZ', 'HK', 'RS', 'DR'], dtype=object)

# %% [markdown]
# Index(['id', 'country', 'city', 'line', 'phase', 'start_year', 'end_year',
#        'rr', 'length', 'tunnelper', 'tunnel', 'elevated', 'atgrade',
#        'stations', 'platform_length_meters', 'source1', 'cost', 'currency',
#        'year', 'ppp_rate', 'real_cost', 'cost_p_km_millions', 'cheap',
#        'clength', 'ctunnel', 'anglo', 'inflation_index',
#        'real_cost_2021_dollars', 'cost_p_km_2021_dollars', 'source2',
#        'reference', 'unnamed_31', 'unnamed_32'],
#       dtype='object')

# %%
df = transit[['length','country','real_cost_2021_dollars', 'tunnelper']]
df.head()
# Out:
#   length country  real_cost_2021_dollars tunnelper
# 0    7.5      TR              550.341886         1
# 1    5.7      CA             2565.240650  0.877193
# 2    8.6      CA             3014.952287         1
# 3    7.8      CA             4985.450027         1
# 4   15.5      CA             7632.655004      0.57

# %%
df.info()
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 944 entries, 0 to 943
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   length                  942 non-null    object
#  1   country                 944 non-null    object
#  2   real_cost_2021_dollars  883 non-null    float64
#  3   tunnelper               879 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 29.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825 entries, 0 to 943
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   length                  825 non-null    object
#  1   country                 825 non-null    object
#  2   real_cost_2021_dollars  825 non-null    float64
#  3   tunnelper               825 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 32.2+ KB

# %%
df.tunnelper = df.tunnelper.astype('float')
df.length = df.length.astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 825 entries, 0 to 943
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   length                  825 non-null    float64
#  1   country                 825 non-null    object
#  2   real_cost_2021_dollars  825 non-null    float64
#  3   tunnelper               825 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 32.2+ KB

# %%
df.to_csv('sampleData.csv')

# %%
import matplotlib.pyplot as plt
df.plot.scatter(x='length', y='tunnelper')
plt.show()

# %%
df.plot.scatter(x='real_cost_2021_dollars', y='country')
plt.show()

# %%
#scatter plot
import seaborn as sns
# cols_to_plot = [col for col in df.columns if '_pc' in col]

# cols_to_plot = ['length',
#                 'cost/km (millions)',
#                 'cheap?',
#                 'clength',
                # 'ctunnel']

# # remove those we don't want
# cols_to_plot.remove('14_pc_yes') 
# cols_to_plot.remove('23_pc_yes') 
# cols_to_plot.remove('24_pc_yes') 

# kind='reg' adds the line of best fit
ax = sns.pairplot(df, kind='reg') 
plt.show()

# %%
df.length=df.length.astype('float64')

# %%
sns.pairplot(transitcost[cols_to_plot], kind='reg')

# %%
df.info()

# %% [markdown]
# ## Standardising Data

# %%
# see https://scikit-learn.org/stable/modules/preprocessing.html for standardization
from sklearn import preprocessing
scaler = preprocessing.StandardScaler().fit(df)

# as in the previous lecture, 
# the scaler returns a numpy array, so we cast this as a DataFrame 
# and need to specify the column names and index
df_scaled = pd.DataFrame(scaler.transform(df), 
                         columns=df.columns, index=df.index)

# %%
# clustering
from sklearn.cluster import KMeans

# Drop NaN
df_scaled = df_scaled.dropna()
kmeans = KMeans(n_clusters=6, random_state=1).fit(df_scaled)
print(kmeans)

# %%
kmeans.cluster_centers_

# %%
df_scaled['cluster_id'] = kmeans.labels_

# %%
# verify that we got the same result as before
df_scaled.groupby('cluster_id').size()

# %%
ax = sns.pairplot(df_scaled, hue='cluster_id', )

# %%
# code from https://matplotlib.org/stable/gallery/specialty_plots/radar_chart.html
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D

def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta

# %%
def radar_plot(kmeans, df_scaled):
    N  = kmeans.cluster_centers_.shape[1]  # number of columns / variables
    k = kmeans.n_clusters
    theta = radar_factory(N, frame='polygon')
    data = kmeans.cluster_centers_.T  # the T means transpose
    spoke_labels = [col for col in df_scaled.columns if col!='cluster_id']
    fig, ax = plt.subplots(figsize=(4, 4),
                                subplot_kw=dict(projection='radar'))
    fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

    ax.plot(theta, data) #, color=color)
    ax.set_varlabels(spoke_labels)

    # add legend relative to top-left plot
    labels = ['Cluster {}'.format(kk) for kk in range(k)]
    ax.legend(labels, loc=(0.95, .95),
                                labelspacing=0.1, fontsize=7)

# %%
radar_plot(kmeans, df_scaled)

# %%
cluster_id
0      8
1      7
2     85
3    471
4     45
dtype: int64
